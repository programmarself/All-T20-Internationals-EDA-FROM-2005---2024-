# %% [markdown]
# # <b> Exploratory Data Analysis on Cricket T20 Internationals From 2005-2024

# %% [markdown]
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨💻Author: Irfan Ullah Khan</h1>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/programmarself)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/programmarself)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/irfan-ullah-khan-4a2871208/)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Profile-red?style=for-the-badge&logo=youtube)](https://www.youtube.com/@irfanullahkhan7748)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/programmar.person.5)
# [![TikTok](https://img.shields.io/badge/TikTok-Profile-black?style=for-the-badge&logo=tiktok)](https://www.tiktok.com/@world_changing_words)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/programmarself)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/programmar.person.5/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:programmarself@gmail.com)

# %% [markdown]
# ### <b>About Dataset</b>
#
# This extensive dataset serves as a comprehensive repository of historical information regarding T20 International (T20I) cricket matches dating back to the inception of the format. T20I cricket is renowned for its thrilling encounters, and this dataset meticulously documents the particulars of these matches. It stands as a valuable resource for cricket enthusiasts, statisticians, and analysts eager to delve into and dissect T20I cricket data.
#
# <b> Key Features:</b>
#
# - Match Details: Thorough information pertaining to each T20I match, encompassing match date, location, and format.
#
# - Teams and Players: In-depth details about the participating teams, encompassing player names, roles, and batting/bowling statistics).
# - Match Outcomes: Insights into match results, encompassing the victorious team and the margin of victory.
# - Player of the Match: Recognition of the standout player in each T20I match.
# - Umpires and Match Referees: Particulars of the officials responsible for overseeing the match.
# - Toss Details: Revelations about the toss winner's decisions, which can significantly influence the game's trajectory.
# - Venue Information: Location specifics, including stadium name, city, and country.

# %% [markdown]
# # Importing Liabraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading datasets

# %%
# All matches records
matches_data = pd.read_csv("/content/t20i_Matches_Data.csv")

# Players information
players_info = pd.read_csv("/content/players_info.csv")

#Batting Stats
batting_data = pd.read_csv("/content/t20i_Batting_Card.csv")

#Bowling Stats
bowling_data = pd.read_csv("/content/t20i_Bowling_Card.csv")

# %% [markdown]
# ### Understanding and cleaning matches data

# %%
matches_data.head()
# Out:
#    T20I Match No  Match ID                              Match Name  Series ID  \
# 0             52    291356            Australia Vs India Only T20I     291355
# 1             54    300436         New Zealand Vs England 2Nd T20I     300418
# 2             65    361531  Netherlands Vs Scotland 2Nd Semi Final     353665
# 3             66    354459     Kenya Vs Scotland 3Rd Place Playoff     353665
# 4             69    361653         Sri Lanka Vs Zimbabwe 1St Match     361644
#
#                                          Series Name  Match Date Match Format  \
# 0          India tour of Australia  - 2007 (2007/08)  2008-02-01          T20
# 1      England tour of New Zealand  - 2008 (2007/08)  2008-02-07          T20
# 2  ICC World Twenty20 Qualifier Bermuda, Canada, ...  2008-08-04          T20
# 3  ICC World Twenty20 Qualifier Bermuda, Canada, ...  2008-08-04          T20
# 4              T20 Canada in Canada - 2008 (2008/09)  2008-10-10          T20
#
#    Team1 ID Team1 Name  Team1 Captain  ...    Umpire 2  Match Referee  \
# 0         6      India           7593  ...  SJA Taufel       JJ Crowe
# 1         1    England           2314  ...  GAV Baxter       AG Hurst
# 2        30   Scotland          45548  ...  PK Baldwin       BC Broad
# 3        26      Kenya           2265  ...  PK Baldwin       BC Broad
# 4         9   Zimbabwe          45326  ...   MR Benson       JJ Crowe
#
#    Toss Winner  Toss Winner Choice Match Winner  \
# 0        India                 bat    Australia
# 1      England                 bat      England
# 2  Netherlands                bowl  Netherlands
# 3        Kenya                 bat     Scotland
# 4    Sri Lanka                bowl    Sri Lanka
#
#                                    Match Result Text  MOM Player  \
# 0  Australia won by 9 wickets (with 52 balls rema...      8876.0
# 1                             England won by 50 runs      2314.0
# 2  Netherlands won by 5 wickets (with 12 balls re...     45358.0
# 3  Scotland won by 9 wickets (with 11 balls remai...     45548.0
# 4  Sri Lanka won by 5 wickets (with 6 balls remai...     50377.0
#
#                                     Team1 Playing 11  \
# 0  ['7773', '7781', '8813', '8742', '48405', '759...
# 1  ['11556', '44660', '8107', '7822', '2314', '63...
# 2  ['45548', '46048', '46142', '8221', '4334', '4...
# 3  ['10364', '2264', '49383', '2265', '2268', '50...
# 4  ['10639', '10423', '47619', '10421', '21364', ...
#
#                                     Team2 Playing 11  \
# 0  ['4176', '8876', '6253', '6256', '4382', '1198...
# 1  ['44946', '10384', '44930', '10381', '9570', '...
# 2  ['10323', '48655', '6362', '49443', '45358', '...
# 3  ['45548', '46048', '46142', '8221', '4334', '4...
# 4  ['48468', '7419', '15273', '8195', '6315', '48...
#
#                                        Debut Players
# 0                        ['11984', '49327', '48319']
# 1                                 ['47488', '10325']
# 2                                                 []
# 3                                 ['50293', '50293']
# 4  ['50377', '47210', '12209', '15273', '48468', ...
#
# [5 rows x 33 columns]

# %%
matches_data.columns
# Out:
# Index(['T20I Match No', 'Match ID', 'Match Name', 'Series ID', 'Series Name',
#        'Match Date', 'Match Format', 'Team1 ID', 'Team1 Name', 'Team1 Captain',
#        'Team1 Runs Scored', 'Team1 Wickets Fell', 'Team1 Extras Rec',
#        'Team2 ID', 'Team2 Name', 'Team2 Captain', 'Team2 Runs Scored',
#        'Team2 Wickets Fell', 'Team2 Extras Rec', 'Match Venue (Stadium)',
#        'Match Venue (City)', 'Match Venue (Country)', 'Umpire 1', 'Umpire 2',
#        'Match Referee', 'Toss Winner', 'Toss Winner Choice', 'Match Winner',
#        'Match Result Text', 'MOM Player', 'Team1 Playing 11',
#        'Team2 Playing 11', 'Debut Players'],
#       dtype='object')

# %%
matches_data.shape
# Out:
# (2411, 33)

# %%
# Renaming columns
new_col = []
for col_name in matches_data.columns.to_list():
    new_col.append(col_name.replace(" ","_").lower())

matches_data.columns = new_col

# %%
matches_data.columns
# Out:
# Index(['t20i_match_no', 'match_id', 'match_name', 'series_id', 'series_name',
#        'match_date', 'match_format', 'team1_id', 'team1_name', 'team1_captain',
#        'team1_runs_scored', 'team1_wickets_fell', 'team1_extras_rec',
#        'team2_id', 'team2_name', 'team2_captain', 'team2_runs_scored',
#        'team2_wickets_fell', 'team2_extras_rec', 'match_venue_(stadium)',
#        'match_venue_(city)', 'match_venue_(country)', 'umpire_1', 'umpire_2',
#        'match_referee', 'toss_winner', 'toss_winner_choice', 'match_winner',
#        'match_result_text', 'mom_player', 'team1_playing_11',
#        'team2_playing_11', 'debut_players'],
#       dtype='object')

# %%
matches_data.head()
# Out:
#    t20i_match_no  match_id                              match_name  series_id  \
# 0             52    291356            Australia Vs India Only T20I     291355
# 1             54    300436         New Zealand Vs England 2Nd T20I     300418
# 2             65    361531  Netherlands Vs Scotland 2Nd Semi Final     353665
# 3             66    354459     Kenya Vs Scotland 3Rd Place Playoff     353665
# 4             69    361653         Sri Lanka Vs Zimbabwe 1St Match     361644
#
#                                          series_name  match_date match_format  \
# 0          India tour of Australia  - 2007 (2007/08)  2008-02-01          T20
# 1      England tour of New Zealand  - 2008 (2007/08)  2008-02-07          T20
# 2  ICC World Twenty20 Qualifier Bermuda, Canada, ...  2008-08-04          T20
# 3  ICC World Twenty20 Qualifier Bermuda, Canada, ...  2008-08-04          T20
# 4              T20 Canada in Canada - 2008 (2008/09)  2008-10-10          T20
#
#    team1_id team1_name  team1_captain  ...    umpire_2  match_referee  \
# 0         6      India           7593  ...  SJA Taufel       JJ Crowe
# 1         1    England           2314  ...  GAV Baxter       AG Hurst
# 2        30   Scotland          45548  ...  PK Baldwin       BC Broad
# 3        26      Kenya           2265  ...  PK Baldwin       BC Broad
# 4         9   Zimbabwe          45326  ...   MR Benson       JJ Crowe
#
#    toss_winner  toss_winner_choice match_winner  \
# 0        India                 bat    Australia
# 1      England                 bat      England
# 2  Netherlands                bowl  Netherlands
# 3        Kenya                 bat     Scotland
# 4    Sri Lanka                bowl    Sri Lanka
#
#                                    match_result_text  mom_player  \
# 0  Australia won by 9 wickets (with 52 balls rema...      8876.0
# 1                             England won by 50 runs      2314.0
# 2  Netherlands won by 5 wickets (with 12 balls re...     45358.0
# 3  Scotland won by 9 wickets (with 11 balls remai...     45548.0
# 4  Sri Lanka won by 5 wickets (with 6 balls remai...     50377.0
#
#                                     team1_playing_11  \
# 0  ['7773', '7781', '8813', '8742', '48405', '759...
# 1  ['11556', '44660', '8107', '7822', '2314', '63...
# 2  ['45548', '46048', '46142', '8221', '4334', '4...
# 3  ['10364', '2264', '49383', '2265', '2268', '50...
# 4  ['10639', '10423', '47619', '10421', '21364', ...
#
#                                     team2_playing_11  \
# 0  ['4176', '8876', '6253', '6256', '4382', '1198...
# 1  ['44946', '10384', '44930', '10381', '9570', '...
# 2  ['10323', '48655', '6362', '49443', '45358', '...
# 3  ['45548', '46048', '46142', '8221', '4334', '4...
# 4  ['48468', '7419', '15273', '8195', '6315', '48...
#
#                                        debut_players
# 0                        ['11984', '49327', '48319']
# 1                                 ['47488', '10325']
# 2                                                 []
# 3                                 ['50293', '50293']
# 4  ['50377', '47210', '12209', '15273', '48468', ...
#
# [5 rows x 33 columns]

# %%
#Looking for null values
matches_data.isna().sum()
# Out:
# t20i_match_no              0
# match_id                   0
# match_name                 0
# series_id                  0
# series_name                0
# match_date                11
# match_format               0
# team1_id                   0
# team1_name                 0
# team1_captain              0
# team1_runs_scored         13
# team1_wickets_fell        13
# team1_extras_rec          13
# team2_id                   0
# team2_name                 0
# team2_captain              0
# team2_runs_scored         46
# team2_wickets_fell        46
# team2_extras_rec          46
# match_venue_(stadium)      0
# match_venue_(city)         0
# match_venue_(country)      0
# umpire_1                   2
# umpire_2                   2
# match_referee            441
# toss_winner                1
# toss_winner_choice        10
# match_winner              91
# match_result_text          0
# mom_player               297
# team1_playing_11           0
# team2_playing_11           0
# debut_players              0
# dtype: int64

# %%
# Dropping Redundant columns
matches_data.drop(columns=['match_referee', 'umpire_1', 'umpire_2'], inplace=True)

# %%
matches_data.head(2)
# Out:
#    t20i_match_no  match_id                       match_name  series_id  \
# 0             52    291356     Australia Vs India Only T20I     291355
# 1             54    300436  New Zealand Vs England 2Nd T20I     300418
#
#                                      series_name  match_date match_format  \
# 0      India tour of Australia  - 2007 (2007/08)  2008-02-01          T20
# 1  England tour of New Zealand  - 2008 (2007/08)  2008-02-07          T20
#
#    team1_id team1_name  team1_captain  ...  match_venue_(city)  \
# 0         6      India           7593  ...           Melbourne
# 1         1    England           2314  ...        Christchurch
#
#    match_venue_(country)  toss_winner  toss_winner_choice match_winner  \
# 0              Australia        India                 bat    Australia
# 1            New Zealand      England                 bat      England
#
#                                    match_result_text  mom_player  \
# 0  Australia won by 9 wickets (with 52 balls rema...      8876.0
# 1                             England won by 50 runs      2314.0
#
#                                     team1_playing_11  \
# 0  ['7773', '7781', '8813', '8742', '48405', '759...
# 1  ['11556', '44660', '8107', '7822', '2314', '63...
#
#                                     team2_playing_11  \
# 0  ['4176', '8876', '6253', '6256', '4382', '1198...
# 1  ['44946', '10384', '44930', '10381', '9570', '...
#
#                  debut_players
# 0  ['11984', '49327', '48319']
# 1           ['47488', '10325']
#
# [2 rows x 30 columns]

# %%
matches_data.sort_values('t20i_match_no', inplace=True)

# %%
matches_data
# Out:
#       t20i_match_no  match_id                                match_name  \
# 10                1    211048        New Zealand Vs Australia Only T20I
# 11                2    211028            England Vs Australia Only T20I
# 12                3    222678     South Africa Vs New Zealand Only T20I
# 13                4    226374       Australia Vs South Africa Only T20I
# 14                5    237242      New Zealand Vs West Indies Only T20I
# ...             ...       ...                                       ...
# 2406           2407   1373581           West Indies Vs England 3Rd T20I
# 2407           2408   1412221   Mozambique Vs Rwanda 11Th Match Group A
# 2408           2409   1412222  Ghana Vs Sierra Leone 12Th Match Group B
# 2409           2410   1412223         Botswana Vs Uganda 1St Semi Final
# 2410           2411   1412224            Kenya Vs Malawi 2Nd Semi Final
#
#       series_id                                        series_name  \
# 10       238218    Australia tour of New Zealand  - 2005 (2004/05)
# 11       238219  Australia tour of England and Scotland  - 2005...
# 12       238166  New Zealand tour of South Africa  - 2005 (2005...
# 13       226335   South Africa tour of Australia  - 2005 (2005/06)
# 14       237244  West Indies tour of New Zealand  - 2006 (2005/06)
# ...         ...                                                ...
# 2406    1373560      England tour of West Indies  - 2023 (2023/24)
# 2407    1412206  Africa Cricket Association Cup in South Africa...
# 2408    1412206  Africa Cricket Association Cup in South Africa...
# 2409    1412206  Africa Cricket Association Cup in South Africa...
# 2410    1412206  Africa Cricket Association Cup in South Africa...
#
#       match_date match_format  team1_id    team1_name  team1_captain  ...  \
# 10           NaN          T20         2     Australia           2230  ...
# 11           NaN          T20         1       England           4709  ...
# 12           NaN          T20         3  South Africa          10406  ...
# 13           NaN          T20         2     Australia           2230  ...
# 14           NaN          T20         4   West Indies           2120  ...
# ...          ...          ...       ...           ...            ...  ...
# 2406  2023-12-16          T20         4   West Indies          80425  ...
# 2407  2023-12-17          T20       191        Rwanda         103210  ...
# 2408  2023-12-17          T20       196  Sierra Leone          96946  ...
# 2409  2023-12-18          T20       116      Botswana          53245  ...
# 2410  2023-12-18          T20        26         Kenya          61834  ...
#
#       match_venue_(city)  match_venue_(country)   toss_winner  \
# 10              Auckland            New Zealand     Australia
# 11           Southampton                England       England
# 12          Johannesburg           South Africa   New Zealand
# 13              Brisbane              Australia     Australia
# 14              Auckland            New Zealand   New Zealand
# ...                  ...                    ...           ...
# 2406         St George's            West Indies       England
# 2407              Benoni           South Africa        Rwanda
# 2408              Benoni           South Africa  Sierra Leone
# 2409              Benoni           South Africa        Uganda
# 2410              Benoni           South Africa         Kenya
#
#       toss_winner_choice match_winner  \
# 10                   bat    Australia
# 11                   bat      England
# 12                  bowl  New Zealand
# 13                   bat    Australia
# 14                  bowl          NaN
# ...                  ...          ...
# 2406                bowl      England
# 2407                 bat   Mozambique
# 2408                 bat        Ghana
# 2409                bowl       Uganda
# 2410                 bat        Kenya
#
#                                       match_result_text  mom_player  \
# 10                             Australia won by 44 runs      2230.0
# 11                              England won by 100 runs      8107.0
# 12    New Zealand won by 5 wickets (with 12 balls re...     11922.0
# 13                             Australia won by 95 runs      2066.0
# 14                                           Match tied     45554.0
# ...                                                 ...         ...
# 2406   England won by 7 wickets (with 1 ball remaining)     72363.0
# 2407  Mozambique won by 5 wickets (with 19 balls rem...    114181.0
# 2408    Ghana won by 2 wickets (with 2 balls remaining)    114179.0
# 2409  Uganda won by 10 wickets (with 88 balls remain...    102781.0
# 2410                   Kenya won by 4 runs (DLS method)     69307.0
#
#                                        team1_playing_11  \
# 10    ['4176', '8876', '4382', '2230', '2066', '6259...
# 11    ['3865', '34719', '4271', '8107', '4709', '231...
# 12    ['2239', '10406', '2232', '2347', '6335', '394...
# 13    ['9235', '2066', '2230', '4382', '8876', '6256...
# 14    ['7568', '7406', '10460', '45554', '6401', '21...
# ...                                                 ...
# 2406  ['72399', '56832', '70405', '68405', '80425', ...
# 2407  ['97081', '109780', '103210', '110311', '10322...
# 2408  ['96946', '114179', '71199', '116528', '96945'...
# 2409  ['53245', '103973', '108745', '55147', '68480'...
# 2410  ['63319', '21463', '53171', '56793', '69307', ...
#
#                                        team2_playing_11  \
# 10    ['10384', '2121', '7410', '9570', '5619', '193...
# 11    ['4176', '2119', '4382', '8876', '6256', '2230...
# 12    ['11922', '2121', '2235', '9633', '5619', '957...
# 13    ['10406', '3978', '2347', '3947', '2228', '223...
# 14    ['10311', '2121', '2235', '9570', '1939', '356...
# ...                                                 ...
# 2406  ['72363', '53271', '83741', '59832', '84027', ...
# 2407  ['68522', '56282', '103114', '110553', '64398'...
# 2408  ['98599', '103129', '58544', '98604', '98607',...
# 2409  ['49195', '66273', '110336', '60488', '75965',...
# 2410  ['103947', '103953', '103952', '104842', '6538...
#
#                                           debut_players
# 10    ['4176', '4176', '10316', '4382', '10384', '10...
# 11    ['4271', '7023', '2160', '34719', '2286', '228...
# 12    ['9505', '6343', '4086', '7540', '10406', '234...
# 13    ['4013', '3978', '6426', '9429', '9630', '1040...
# 14    ['7568', '7406', '7406', '21239', '21239', '47...
# ...                                                 ...
# 2406                                                 []
# 2407                                                 []
# 2408                                                 []
# 2409                                                 []
# 2410                                                 []
#
# [2411 rows x 30 columns]

# %%
# Converting date values to Date Time format i.e Timestamp

matches_data['match_date'] = pd.to_datetime(matches_data['match_date'])

# %%
# Finding out time range of data
print(matches_data['match_date'].min())
print(matches_data['match_date'].max())
# Out:
# 2006-06-15 00:00:00
# 2023-12-18 00:00:00

# %% [markdown]
# ### Understanding & Cleaning player information data

# %%
players_info.head()
# Out:
#    player_id  player_object_id       player_name         dob  dod gender  \
# 0      93957           1046619       Avinash Pai  1982-01-24  NaN      M
# 1       2182             51462  Sherwin Campbell  1970-11-01  NaN      M
# 2      48391             56194       Tamim Iqbal  1989-03-20  NaN      M
# 3       2198             55935        Javed Omar  1976-11-25  NaN      M
# 4      52290            298438         Jason Roy  1990-07-21  NaN      M
#
#     batting_style       bowling_style  country_id  \
# 0  right-hand bat  right-arm offbreak        18.0
# 1  right-hand bat    right-arm medium         4.0
# 2   left-hand bat                 NaN        25.0
# 3  right-hand bat            legbreak        25.0
# 4  right-hand bat                 NaN         1.0
#
#                                            image_url  \
# 0                                                NaN
# 1  https://img1.hscicdn.com/image/upload/f_auto,t...
# 2  https://img1.hscicdn.com/image/upload/f_auto,t...
# 3  https://img1.hscicdn.com/image/upload/f_auto,t...
# 4  https://img1.hscicdn.com/image/upload/f_auto,t...
#
#                                       image_metadata
# 0                                                NaN
# 1  {'id': 326616, 'url': '/db/PICTURES/CMS/326600...
# 2  {'id': 303166, 'url': '/db/PICTURES/CMS/303100...
# 3  {'id': 302990, 'url': '/db/PICTURES/CMS/302900...
# 4  {'id': 303963, 'url': '/db/PICTURES/CMS/303900...

# %%
players_info.shape
# Out:
# (6697, 11)

# %%
players_info.isna().sum()
# Out:
# player_id              0
# player_object_id       0
# player_name            0
# dob                   26
# dod                 5439
# gender                 0
# batting_style         97
# bowling_style       1160
# country_id             2
# image_url           2957
# image_metadata      2957
# dtype: int64

# %%
players_info['gender'].value_counts()
# Out:
# M    6696
# F       1
# Name: gender, dtype: int64

# %%
# Dropping Redundant Columns
players_info.drop(columns=['gender', 'image_url', 'image_metadata'], inplace=True)

# %%
players_info.head()
# Out:
#    player_id  player_object_id       player_name         dob  dod  \
# 0      93957           1046619       Avinash Pai  1982-01-24  NaN
# 1       2182             51462  Sherwin Campbell  1970-11-01  NaN
# 2      48391             56194       Tamim Iqbal  1989-03-20  NaN
# 3       2198             55935        Javed Omar  1976-11-25  NaN
# 4      52290            298438         Jason Roy  1990-07-21  NaN
#
#     batting_style       bowling_style  country_id
# 0  right-hand bat  right-arm offbreak        18.0
# 1  right-hand bat    right-arm medium         4.0
# 2   left-hand bat                 NaN        25.0
# 3  right-hand bat            legbreak        25.0
# 4  right-hand bat                 NaN         1.0

# %% [markdown]
# ### Understanding & Cleaning batting stats data

# %%
batting_data.shape
# Out:
# (52419, 13)

# %%
batting_data.head(20)
# Out:
#     Match ID  innings      team  batsman  runs  balls  fours  sixes  \
# 0     361657        1  Zimbabwe  10423.0  53.0   38.0    5.0    3.0
# 1     361657        1  Zimbabwe  49282.0  12.0   22.0    2.0    0.0
# 2     361657        1  Zimbabwe  47619.0   8.0   26.0    0.0    0.0
# 3     361657        1  Zimbabwe  10421.0   4.0    6.0    1.0    0.0
# 4     361660        1  Pakistan  11647.0  44.0   41.0    4.0    1.0
# 5     361657        1  Zimbabwe  45252.0   4.0    8.0    0.0    0.0
# 6     361660        1  Pakistan  47738.0   0.0    5.0    0.0    0.0
# 7     361657        1  Zimbabwe  10639.0   0.0    1.0    0.0    0.0
# 8     361660        1  Pakistan   4169.0  14.0   13.0    1.0    0.0
# 9     361531        1  Scotland  45548.0  22.0   27.0    1.0    0.0
# 10    361660        1  Pakistan  10439.0   0.0    4.0    0.0    0.0
# 11    361657        1  Zimbabwe  49274.0   7.0    9.0    1.0    0.0
# 12    361531        1  Scotland  46048.0  40.0   44.0    4.0    2.0
# 13    361660        1  Pakistan   8270.0  19.0   19.0    1.0    1.0
# 14    361657        1  Zimbabwe  51554.0   1.0    6.0    0.0    0.0
# 15    361531        1  Scotland  46142.0  25.0   27.0    1.0    0.0
# 16    361660        1  Pakistan  19596.0  23.0   25.0    2.0    0.0
# 17    361657        1  Zimbabwe  45326.0   0.0    2.0    0.0    0.0
# 18    361531        1  Scotland   8221.0   0.0    1.0    0.0    0.0
# 19    361657        1  Zimbabwe   7432.0   0.0    2.0    0.0    0.0
#
#     strikeRate  isOut wicketType            fielders   bowler
# 0       139.47   True    run out           ['47099']      NaN
# 1        54.54   True     caught           ['47738']   8270.0
# 2        30.76   True     caught           ['19596']  47099.0
# 3        66.66   True     caught            ['8270']   4169.0
# 4       107.31   True     caught           ['15267']  50377.0
# 5        50.00   True     caught            ['9257']  47099.0
# 6         0.00   True     caught           ['11271']  11271.0
# 7         0.00   True     caught            ['9257']  44908.0
# 8       107.69   True     caught            ['8203']  15267.0
# 9        81.48   True     bowled                 NaN  45001.0
# 10        0.00   True    run out           ['10412']      NaN
# 11       77.77   True   stumping            ['9257']  47099.0
# 12       90.90   True    run out  ['45001', '48503']      NaN
# 13      100.00   True     caught            ['8203']  50377.0
# 14       16.66   True    run out           ['47738']      NaN
# 15       92.59   True    run out            ['5694']      NaN
# 16       92.00  False    not out               ['-']      NaN
# 17        0.00  False    not out               ['-']      NaN
# 18        0.00   True     caught           ['48503']  45358.0
# 19        0.00  False    not out               ['-']      NaN

# %%
batting_data.tail(20)
# Out:
#        Match ID  innings      team   batsman  runs  balls  fours  sixes  \
# 52399   1412220        2  Botswana   53245.0  12.0   11.0    1.0    0.0
# 52400   1412224        2    Malawi  103952.0   5.0    5.0    0.0    0.0
# 52401   1412220        2  Botswana  103191.0  19.0   39.0    1.0    0.0
# 52402   1412224        2    Malawi  104842.0   4.0    3.0    0.0    0.0
# 52403   1412220        2  Botswana  108745.0  13.0   13.0    1.0    0.0
# 52404   1412224        2    Malawi   65386.0   NaN    NaN    NaN    NaN
# 52405   1412220        2  Botswana  103973.0  25.0   25.0    0.0    1.0
# 52406   1412224        2    Malawi  113234.0   NaN    NaN    NaN    NaN
# 52407   1412220        2  Botswana   98611.0   3.0    7.0    0.0    0.0
# 52408   1412224        2    Malawi  113229.0   NaN    NaN    NaN    NaN
# 52409   1412220        2  Botswana   55147.0   0.0    1.0    0.0    0.0
# 52410   1412224        2    Malawi  114011.0   NaN    NaN    NaN    NaN
# 52411   1412220        2  Botswana   68480.0   7.0   16.0    0.0    0.0
# 52412   1412224        2    Malawi  110420.0   NaN    NaN    NaN    NaN
# 52413   1412220        2  Botswana  112124.0   1.0    1.0    0.0    0.0
# 52414   1412224        2    Malawi  110423.0   NaN    NaN    NaN    NaN
# 52415   1412220        2  Botswana   71147.0   1.0    5.0    0.0    0.0
# 52416   1412224        2    Malawi  114966.0   NaN    NaN    NaN    NaN
# 52417   1412220        2  Botswana   98613.0   1.0    2.0    0.0    0.0
# 52418   1412220        2  Botswana  106223.0   NaN    NaN    NaN    NaN
#
#        strikeRate  isOut wicketType    fielders  bowler
# 52399      109.09   True     caught   ['56793']     NaN
# 52400      100.00  False    not out       ['-']     NaN
# 52401       48.71   True     caught   ['53203']     NaN
# 52402      133.33  False    not out       ['-']     NaN
# 52403      100.00   True     caught   ['53203']     NaN
# 52404         NaN  False        DNB         NaN     NaN
# 52405      100.00   True     caught   ['56793']     NaN
# 52406         NaN  False        DNB         NaN     NaN
# 52407       42.85   True     caught   ['53203']     NaN
# 52408         NaN  False        DNB         NaN     NaN
# 52409        0.00   True     bowled         NaN     NaN
# 52410         NaN  False        DNB         NaN     NaN
# 52411       43.75   True     caught  ['113058']     NaN
# 52412         NaN  False        DNB         NaN     NaN
# 52413      100.00   True    run out   ['68249']     NaN
# 52414         NaN  False        DNB         NaN     NaN
# 52415       20.00   True     bowled         NaN     NaN
# 52416         NaN  False        DNB         NaN     NaN
# 52417       50.00  False    not out       ['-']     NaN
# 52418         NaN  False        DNB         NaN     NaN

# %%
batting_data.sample(10)
# Out:
#        Match ID  innings         team   batsman  runs  balls  fours  sixes  \
# 4901     527013        2     Zimbabwe   47618.0  22.0   17.0    2.0    0.0
# 26924   1263472        2    Sri Lanka   78229.0   0.0    5.0    0.0    0.0
# 21918   1201670        2        Spain   93983.0   NaN    NaN    NaN    NaN
# 2632     403375        1     Pakistan   19930.0   NaN    NaN    NaN    NaN
# 4115     446961        2      England    8107.0   1.0    2.0    0.0    0.0
# 8722     690351        2   Bangladesh   52364.0   NaN    NaN    NaN    NaN
# 21213   1199536        2        Kenya   98584.0   3.0   14.0    0.0    0.0
# 51751   1411434        1     Cameroon  110563.0   0.0    3.0    0.0    0.0
# 3600     426723        2  New Zealand   10386.0  22.0   21.0    0.0    0.0
# 34304   1307478        2     Scotland   76927.0   3.0    6.0    0.0    0.0
#
#        strikeRate  isOut wicketType           fielders   bowler
# 4901       129.41   True    run out  ['9989', '10384']      NaN
# 26924        0.00   True     bowled                NaN  64244.0
# 21918         NaN  False        DNB                NaN      NaN
# 2632          NaN  False        DNB                NaN      NaN
# 4115        50.00   True     caught          ['12049']  10130.0
# 8722          NaN  False        DNB                NaN      NaN
# 21213       21.42   True     caught          ['61866']  47469.0
# 51751        0.00   True     caught          ['56793']      NaN
# 3600       104.76   True     caught          ['44908']  19930.0
# 34304       50.00  False    not out              ['-']      NaN

# %%
#Checking null values
batting_data.isna().sum()
# Out:
# Match ID          0
# innings           0
# team             26
# batsman          26
# runs          13542
# balls         13542
# fours         13542
# sixes         13542
# strikeRate    13542
# isOut            26
# wicketType       26
# fielders      22560
# bowler        26771
# dtype: int64

# %%
# Dropping rows with null values in runs, balls, fours, sixes, strikeRate
batting_data.dropna(subset=['runs','balls','fours','sixes', 'strikeRate'], inplace=True)

# %%
batting_data.isna().sum()
# Out:
# Match ID          0
# innings           0
# team              0
# batsman           0
# runs              0
# balls             0
# fours             0
# sixes             0
# strikeRate        0
# isOut             0
# wicketType        0
# fielders       9018
# bowler        13229
# dtype: int64

# %%
batting_data
# Out:
#        Match ID  innings      team   batsman  runs  balls  fours  sixes  \
# 0        361657        1  Zimbabwe   10423.0  53.0   38.0    5.0    3.0
# 1        361657        1  Zimbabwe   49282.0  12.0   22.0    2.0    0.0
# 2        361657        1  Zimbabwe   47619.0   8.0   26.0    0.0    0.0
# 3        361657        1  Zimbabwe   10421.0   4.0    6.0    1.0    0.0
# 4        361660        1  Pakistan   11647.0  44.0   41.0    4.0    1.0
# ...         ...      ...       ...       ...   ...    ...    ...    ...
# 52409   1412220        2  Botswana   55147.0   0.0    1.0    0.0    0.0
# 52411   1412220        2  Botswana   68480.0   7.0   16.0    0.0    0.0
# 52413   1412220        2  Botswana  112124.0   1.0    1.0    0.0    0.0
# 52415   1412220        2  Botswana   71147.0   1.0    5.0    0.0    0.0
# 52417   1412220        2  Botswana   98613.0   1.0    2.0    0.0    0.0
#
#        strikeRate  isOut wicketType    fielders   bowler
# 0          139.47   True    run out   ['47099']      NaN
# 1           54.54   True     caught   ['47738']   8270.0
# 2           30.76   True     caught   ['19596']  47099.0
# 3           66.66   True     caught    ['8270']   4169.0
# 4          107.31   True     caught   ['15267']  50377.0
# ...           ...    ...        ...         ...      ...
# 52409        0.00   True     bowled         NaN      NaN
# 52411       43.75   True     caught  ['113058']      NaN
# 52413      100.00   True    run out   ['68249']      NaN
# 52415       20.00   True     bowled         NaN      NaN
# 52417       50.00  False    not out       ['-']      NaN
#
# [38877 rows x 13 columns]

# %%
batting_data.rename(columns= {'Match ID' : 'match_id'}, inplace=True)
batting_data
# Out:
#        match_id  innings      team   batsman  runs  balls  fours  sixes  \
# 0        361657        1  Zimbabwe   10423.0  53.0   38.0    5.0    3.0
# 1        361657        1  Zimbabwe   49282.0  12.0   22.0    2.0    0.0
# 2        361657        1  Zimbabwe   47619.0   8.0   26.0    0.0    0.0
# 3        361657        1  Zimbabwe   10421.0   4.0    6.0    1.0    0.0
# 4        361660        1  Pakistan   11647.0  44.0   41.0    4.0    1.0
# ...         ...      ...       ...       ...   ...    ...    ...    ...
# 52409   1412220        2  Botswana   55147.0   0.0    1.0    0.0    0.0
# 52411   1412220        2  Botswana   68480.0   7.0   16.0    0.0    0.0
# 52413   1412220        2  Botswana  112124.0   1.0    1.0    0.0    0.0
# 52415   1412220        2  Botswana   71147.0   1.0    5.0    0.0    0.0
# 52417   1412220        2  Botswana   98613.0   1.0    2.0    0.0    0.0
#
#        strikeRate  isOut wicketType    fielders   bowler
# 0          139.47   True    run out   ['47099']      NaN
# 1           54.54   True     caught   ['47738']   8270.0
# 2           30.76   True     caught   ['19596']  47099.0
# 3           66.66   True     caught    ['8270']   4169.0
# 4          107.31   True     caught   ['15267']  50377.0
# ...           ...    ...        ...         ...      ...
# 52409        0.00   True     bowled         NaN      NaN
# 52411       43.75   True     caught  ['113058']      NaN
# 52413      100.00   True    run out   ['68249']      NaN
# 52415       20.00   True     bowled         NaN      NaN
# 52417       50.00  False    not out       ['-']      NaN
#
# [38877 rows x 13 columns]

# %% [markdown]
# ### Understanding & Cleaning bowling stats data

# %%
bowling_data
# Out:
#        Match ID  innings         team opposition  bowler id  overs  balls  \
# 0        300436        1  New Zealand    England    10303.0    4.0   24.0
# 1        300436        1  New Zealand    England     9711.0    4.0   24.0
# 2        300436        1  New Zealand    England    10325.0    3.0   18.0
# 3        300436        1  New Zealand    England    49108.0    4.0   24.0
# 4        300436        1  New Zealand    England     9570.0    3.0   18.0
# ...         ...      ...          ...        ...        ...    ...    ...
# 28476   1412220        2        Kenya   Botswana    63485.0    3.0   18.0
# 28477   1412220        2        Kenya   Botswana    68249.0    4.0   24.0
# 28478   1412220        2        Kenya   Botswana    53203.0    4.0   24.0
# 28479   1412220        2        Kenya   Botswana   113058.0    4.0   24.0
# 28480   1412220        2        Kenya   Botswana    21463.0    4.0   24.0
#
#        maidens  conceded  wickets  economy  dots  fours  sixes  wides  noballs
# 0          0.0      35.0      1.0     8.75  10.0    3.0    2.0    1.0      0.0
# 1          0.0      45.0      1.0    11.25   5.0    6.0    1.0    1.0      0.0
# 2          0.0      43.0      2.0    14.33   5.0    3.0    4.0    1.0      0.0
# 3          0.0      22.0      2.0     5.50  10.0    1.0    1.0    0.0      0.0
# 4          0.0      25.0      0.0     8.33   8.0    3.0    1.0    0.0      0.0
# ...        ...       ...      ...      ...   ...    ...    ...    ...      ...
# 28476      1.0      10.0      2.0     3.33   NaN    NaN    NaN    0.0      0.0
# 28477      0.0      14.0      2.0     3.50   NaN    NaN    NaN    1.0      0.0
# 28478      0.0      18.0      0.0     4.50   NaN    NaN    NaN    0.0      0.0
# 28479      0.0      21.0      4.0     5.25   NaN    NaN    NaN    3.0      0.0
# 28480      0.0      18.0      0.0     4.50   NaN    NaN    NaN    1.0      0.0
#
# [28481 rows x 16 columns]

# %%
bowling_data.sample(20)
# Out:
#        Match ID  innings         team    opposition  bowler id  overs  balls  \
# 2518     523736        2     Pakistan      Zimbabwe    45170.0    1.0    6.0
# 27253   1400984        1      Nigeria         Ghana   102141.0    2.0   12.0
# 21152   1326826        1   Mozambique      Eswatini   103111.0    1.3    9.0
# 12018   1202010        2     Malaysia       Vanuatu    71052.0    3.1   19.0
# 19196   1317138        2       Serbia      Bulgaria   112445.0    1.5   11.0
# 12780   1217741        1     Malaysia      Thailand    71041.0    4.0   24.0
# 19656   1320975        2       Israel         Spain   112439.0    2.0   12.0
# 9849    1187681        1  New Zealand         India    48928.0    4.0   24.0
# 27524   1404392        2      Namibia      Zimbabwe    63683.0    3.0   18.0
# 20105   1321281        2      Austria    Luxembourg   109665.0    1.0    6.0
# 5579     919603        2     Pakistan      Zimbabwe    24723.0    4.0   24.0
# 7387    1115807        1  New Zealand      Pakistan    67586.0    4.0   24.0
# 23624   1349388        1    Singapore      Malaysia    94203.0    4.0   24.0
# 19755   1320985        2       Israel       Hungary    93967.0    1.0    6.0
# 14554   1272096        1   Bangladesh   New Zealand    54674.0    3.3   21.0
# 10193   1192816        1        Samoa       Vanuatu   105861.0    4.0   24.0
# 5188     875521        2    Hong Kong       Ireland    66839.0    4.0   24.0
# 17821   1298174        2  Netherlands  South Africa    97878.0    4.0   24.0
# 20692   1321484        1  Netherlands      Zimbabwe    61845.0    4.0   24.0
# 22540   1343751        1      Lesotho    Seychelles   110417.0    4.0   24.0
#
#        maidens  conceded  wickets  economy  dots  fours  sixes  wides  noballs
# 2518       0.0       8.0      0.0     8.00   2.0    1.0    0.0    0.0      0.0
# 27253      0.0      11.0      0.0     5.50   4.0    0.0    0.0    0.0      0.0
# 21152      0.0       4.0      1.0     2.66   NaN    NaN    NaN    0.0      0.0
# 12018      0.0      25.0      0.0     7.89   5.0    0.0    1.0    0.0      0.0
# 19196      0.0      27.0      0.0    14.72   4.0    2.0    2.0    1.0      1.0
# 12780      0.0      28.0      1.0     7.00  10.0    1.0    2.0    1.0      0.0
# 19656      0.0      14.0      1.0     7.00   7.0    3.0    0.0    0.0      0.0
# 9849       0.0      21.0      1.0     5.25  11.0    2.0    0.0    0.0      0.0
# 27524      0.0      12.0      1.0     4.00   8.0    0.0    0.0    0.0      0.0
# 20105      0.0       8.0      0.0     8.00   2.0    1.0    0.0    1.0      0.0
# 5579       0.0      27.0      1.0     6.75   8.0    2.0    0.0    1.0      0.0
# 7387       0.0      25.0      0.0     6.25  10.0    1.0    1.0    1.0      0.0
# 23624      0.0      38.0      0.0     9.50   9.0    3.0    2.0    2.0      0.0
# 19755      0.0      11.0      0.0    11.00   3.0    1.0    1.0    0.0      0.0
# 14554      0.0      12.0      4.0     3.42  13.0    1.0    0.0    1.0      0.0
# 10193      0.0      36.0      0.0     9.00   NaN    NaN    NaN    0.0      0.0
# 5188       0.0      40.0      2.0    10.00  11.0    6.0    1.0    2.0      0.0
# 17821      0.0      20.0      2.0     5.00  15.0    3.0    0.0    0.0      0.0
# 20692      1.0      18.0      3.0     4.50  12.0    1.0    0.0    1.0      0.0
# 22540      0.0      34.0      1.0     8.50   8.0    3.0    1.0    2.0      0.0

# %%
# Checking null values
bowling_data.isna().sum()
# Out:
# Match ID         0
# innings          0
# team            26
# opposition      26
# bowler id       26
# overs           26
# balls           26
# maidens         26
# conceded        26
# wickets         26
# economy         26
# dots          2277
# fours         2277
# sixes         2277
# wides           26
# noballs         26
# dtype: int64

# %%
# Verying Null rows
bowling_data[bowling_data['team'].isna()]
# Out:
#        Match ID  innings team opposition  bowler id  overs  balls  maidens  \
# 369      287859        1  NaN        NaN        NaN    NaN    NaN      NaN
# 370      287859        2  NaN        NaN        NaN    NaN    NaN      NaN
# 881      354461        1  NaN        NaN        NaN    NaN    NaN      NaN
# 882      354461        2  NaN        NaN        NaN    NaN    NaN      NaN
# 5238     876465        1  NaN        NaN        NaN    NaN    NaN      NaN
# 5239     876465        2  NaN        NaN        NaN    NaN    NaN      NaN
# 5262     876467        1  NaN        NaN        NaN    NaN    NaN      NaN
# 5263     876467        2  NaN        NaN        NaN    NaN    NaN      NaN
# 5845     951317        1  NaN        NaN        NaN    NaN    NaN      NaN
# 5846     951317        2  NaN        NaN        NaN    NaN    NaN      NaN
# 9433    1185189        1  NaN        NaN        NaN    NaN    NaN      NaN
# 9434    1185189        2  NaN        NaN        NaN    NaN    NaN      NaN
# 12083   1202242        1  NaN        NaN        NaN    NaN    NaN      NaN
# 12084   1202242        2  NaN        NaN        NaN    NaN    NaN      NaN
# 15406   1275041        1  NaN        NaN        NaN    NaN    NaN      NaN
# 15407   1275041        2  NaN        NaN        NaN    NaN    NaN      NaN
# 22636   1343759        1  NaN        NaN        NaN    NaN    NaN      NaN
# 22637   1343759        2  NaN        NaN        NaN    NaN    NaN      NaN
# 23475   1349141        1  NaN        NaN        NaN    NaN    NaN      NaN
# 23476   1349141        2  NaN        NaN        NaN    NaN    NaN      NaN
# 25207   1381459        1  NaN        NaN        NaN    NaN    NaN      NaN
# 25208   1381459        2  NaN        NaN        NaN    NaN    NaN      NaN
# 25222   1381460        1  NaN        NaN        NaN    NaN    NaN      NaN
# 25224   1381460        2  NaN        NaN        NaN    NaN    NaN      NaN
# 26055   1391336        1  NaN        NaN        NaN    NaN    NaN      NaN
# 26056   1391336        2  NaN        NaN        NaN    NaN    NaN      NaN
#
#        conceded  wickets  economy  dots  fours  sixes  wides  noballs
# 369         NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 370         NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 881         NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 882         NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 5238        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 5239        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 5262        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 5263        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 5845        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 5846        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 9433        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 9434        NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 12083       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 12084       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 15406       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 15407       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 22636       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 22637       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 23475       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 23476       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 25207       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 25208       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 25222       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 25224       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 26055       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN
# 26056       NaN      NaN      NaN   NaN    NaN    NaN    NaN      NaN

# %%
# Dropping these rows
bowling_data.dropna(subset="team", inplace=True)

# %%
bowling_data.isna().sum()
# Out:
# Match ID         0
# innings          0
# team             0
# opposition       0
# bowler id        0
# overs            0
# balls            0
# maidens          0
# conceded         0
# wickets          0
# economy          0
# dots          2251
# fours         2251
# sixes         2251
# wides            0
# noballs          0
# dtype: int64

# %%
bowling_data[bowling_data['dots'].isna()]

# No need to drop these
# Out:
#        Match ID  innings      team  opposition  bowler id  overs  balls  \
# 239      264065        1  Zimbabwe  Bangladesh     4177.0    4.0   24.0
# 240      264065        1  Zimbabwe  Bangladesh    46653.0    3.0   18.0
# 241      264065        1  Zimbabwe  Bangladesh    45252.0    2.0   12.0
# 242      264065        1  Zimbabwe  Bangladesh    45326.0    4.0   24.0
# 243      264065        1  Zimbabwe  Bangladesh    47206.0    4.0   24.0
# ...         ...      ...       ...         ...        ...    ...    ...
# 28476   1412220        2     Kenya    Botswana    63485.0    3.0   18.0
# 28477   1412220        2     Kenya    Botswana    68249.0    4.0   24.0
# 28478   1412220        2     Kenya    Botswana    53203.0    4.0   24.0
# 28479   1412220        2     Kenya    Botswana   113058.0    4.0   24.0
# 28480   1412220        2     Kenya    Botswana    21463.0    4.0   24.0
#
#        maidens  conceded  wickets  economy  dots  fours  sixes  wides  noballs
# 239        0.0      40.0      2.0    10.00   NaN    NaN    NaN    0.0      0.0
# 240        0.0      33.0      1.0    11.00   NaN    NaN    NaN    1.0      1.0
# 241        0.0      22.0      1.0    11.00   NaN    NaN    NaN    3.0      0.0
# 242        0.0      25.0      3.0     6.25   NaN    NaN    NaN    0.0      1.0
# 243        0.0      28.0      1.0     7.00   NaN    NaN    NaN    0.0      0.0
# ...        ...       ...      ...      ...   ...    ...    ...    ...      ...
# 28476      1.0      10.0      2.0     3.33   NaN    NaN    NaN    0.0      0.0
# 28477      0.0      14.0      2.0     3.50   NaN    NaN    NaN    1.0      0.0
# 28478      0.0      18.0      0.0     4.50   NaN    NaN    NaN    0.0      0.0
# 28479      0.0      21.0      4.0     5.25   NaN    NaN    NaN    3.0      0.0
# 28480      0.0      18.0      0.0     4.50   NaN    NaN    NaN    1.0      0.0
#
# [2251 rows x 16 columns]

# %%
bowling_data.rename(columns= {'Match ID' : 'match_id', 'bowler id' : 'bowler_id'}, inplace=True)
bowling_data
# Out:
#        match_id  innings         team opposition  bowler_id  overs  balls  \
# 0        300436        1  New Zealand    England    10303.0    4.0   24.0
# 1        300436        1  New Zealand    England     9711.0    4.0   24.0
# 2        300436        1  New Zealand    England    10325.0    3.0   18.0
# 3        300436        1  New Zealand    England    49108.0    4.0   24.0
# 4        300436        1  New Zealand    England     9570.0    3.0   18.0
# ...         ...      ...          ...        ...        ...    ...    ...
# 28476   1412220        2        Kenya   Botswana    63485.0    3.0   18.0
# 28477   1412220        2        Kenya   Botswana    68249.0    4.0   24.0
# 28478   1412220        2        Kenya   Botswana    53203.0    4.0   24.0
# 28479   1412220        2        Kenya   Botswana   113058.0    4.0   24.0
# 28480   1412220        2        Kenya   Botswana    21463.0    4.0   24.0
#
#        maidens  conceded  wickets  economy  dots  fours  sixes  wides  noballs
# 0          0.0      35.0      1.0     8.75  10.0    3.0    2.0    1.0      0.0
# 1          0.0      45.0      1.0    11.25   5.0    6.0    1.0    1.0      0.0
# 2          0.0      43.0      2.0    14.33   5.0    3.0    4.0    1.0      0.0
# 3          0.0      22.0      2.0     5.50  10.0    1.0    1.0    0.0      0.0
# 4          0.0      25.0      0.0     8.33   8.0    3.0    1.0    0.0      0.0
# ...        ...       ...      ...      ...   ...    ...    ...    ...      ...
# 28476      1.0      10.0      2.0     3.33   NaN    NaN    NaN    0.0      0.0
# 28477      0.0      14.0      2.0     3.50   NaN    NaN    NaN    1.0      0.0
# 28478      0.0      18.0      0.0     4.50   NaN    NaN    NaN    0.0      0.0
# 28479      0.0      21.0      4.0     5.25   NaN    NaN    NaN    3.0      0.0
# 28480      0.0      18.0      0.0     4.50   NaN    NaN    NaN    1.0      0.0
#
# [28455 rows x 16 columns]

# %% [markdown]
# # <b>Performing Exploratory Data Analysis(EDA) for finding useful insights and answering analytical questions.

# %% [markdown]
# # Which country has hosted the most number of matches?

# %%
matches_data.head(2)
# Out:
#     t20i_match_no  match_id                          match_name  series_id  \
# 10              1    211048  New Zealand Vs Australia Only T20I     238218
# 11              2    211028      England Vs Australia Only T20I     238219
#
#                                           series_name match_date match_format  \
# 10    Australia tour of New Zealand  - 2005 (2004/05)        NaT          T20
# 11  Australia tour of England and Scotland  - 2005...        NaT          T20
#
#     team1_id team1_name  team1_captain  ...  match_venue_(city)  \
# 10         2  Australia           2230  ...            Auckland
# 11         1    England           4709  ...         Southampton
#
#     match_venue_(country)  toss_winner  toss_winner_choice match_winner  \
# 10            New Zealand    Australia                 bat    Australia
# 11                England      England                 bat      England
#
#            match_result_text  mom_player  \
# 10  Australia won by 44 runs      2230.0
# 11   England won by 100 runs      8107.0
#
#                                      team1_playing_11  \
# 10  ['4176', '8876', '4382', '2230', '2066', '6259...
# 11  ['3865', '34719', '4271', '8107', '4709', '231...
#
#                                      team2_playing_11  \
# 10  ['10384', '2121', '7410', '9570', '5619', '193...
# 11  ['4176', '2119', '4382', '8876', '6256', '2230...
#
#                                         debut_players
# 10  ['4176', '4176', '10316', '4382', '10384', '10...
# 11  ['4271', '7023', '2160', '34719', '2286', '228...
#
# [2 rows x 30 columns]

# %%
matches_data['match_venue_(country)'].value_counts().nlargest(10)
# Out:
# United Arab Emirates    236
# South Africa            144
# Rwanda                  140
# India                   128
# West Indies             123
# Bangladesh              104
# Australia               101
# Oman                     99
# England                  91
# New Zealand              85
# Name: match_venue_(country), dtype: int64

# %%
# Setting figure size
plt.figure( figsize = (15,5) )

# Setting figure style or theme
sns.set_style('darkgrid')

# Plotting chart
ax = sns.countplot(data=matches_data, x='match_venue_(country)', palette='hls')

# Setting labels with each bar count
for container in ax.containers:
    ax.bar_label(container, label_type="edge", padding=1, size=9, color="black")

# Customizations
plt.tick_params('x', rotation=90)
plt.xlabel("Match venues (countries)")
plt.ylabel("Matches")
plt.title("No. of matches hosted by countries")
plt.yticks([0,25,50,75,100,125,150,175,200,225])

# Show chart
plt.show()
# Out:
# <ipython-input-47-563f56ba76a3>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=matches_data, x='match_venue_(country)', palette='hls')

# %% [markdown]
# <b> From the chart, we can see that United Arab Emirates has hosted the most number of T20I matches till now i.e 236 </b>

# %% [markdown]
# # Top 10 players with most man-of-the-match awards

# %%
matches_data.head(2)
# Out:
#     t20i_match_no  match_id                          match_name  series_id  \
# 10              1    211048  New Zealand Vs Australia Only T20I     238218
# 11              2    211028      England Vs Australia Only T20I     238219
#
#                                           series_name match_date match_format  \
# 10    Australia tour of New Zealand  - 2005 (2004/05)        NaT          T20
# 11  Australia tour of England and Scotland  - 2005...        NaT          T20
#
#     team1_id team1_name  team1_captain  ...  match_venue_(city)  \
# 10         2  Australia           2230  ...            Auckland
# 11         1    England           4709  ...         Southampton
#
#     match_venue_(country)  toss_winner  toss_winner_choice match_winner  \
# 10            New Zealand    Australia                 bat    Australia
# 11                England      England                 bat      England
#
#            match_result_text  mom_player  \
# 10  Australia won by 44 runs      2230.0
# 11   England won by 100 runs      8107.0
#
#                                      team1_playing_11  \
# 10  ['4176', '8876', '4382', '2230', '2066', '6259...
# 11  ['3865', '34719', '4271', '8107', '4709', '231...
#
#                                      team2_playing_11  \
# 10  ['10384', '2121', '7410', '9570', '5619', '193...
# 11  ['4176', '2119', '4382', '8876', '6256', '2230...
#
#                                         debut_players
# 10  ['4176', '4176', '10316', '4382', '10384', '10...
# 11  ['4271', '7023', '2160', '34719', '2286', '228...
#
# [2 rows x 30 columns]

# %%
# Grouping the dataframe by 'mom_player' columns and aggregating the rows by counting the no. of awards
motm_players = matches_data.groupby('mom_player')[['match_id']].count().rename(columns={'match_id' : 'awards'})

# Merging the result dataframe with player info on each unique player id
motm_with_names = motm_players.merge(players_info, left_index=True, right_on='player_id')

# Setting size and theme
plt.figure(figsize=(12,6))
sns.set_style('whitegrid')

# Plotting by 10 largest no. of awards
ax = sns.barplot(x='player_name', y='awards', data=motm_with_names.nlargest(10,'awards'), palette='viridis')

# Customizations
ax.tick_params('x', rotation=45)
ax.set_title("Top 10 players with most MotM awards in T20Is", fontweight = 'bold', fontsize = 15)
ax.set_xlabel('Players', fontweight = 'bold', fontsize = 13)
ax.set_ylabel('No. of awards', fontweight = 'bold', fontsize = 13)

# Setting bar label on each container
for container in ax.containers:
    ax.bar_label(container, padding=-20, size=12, color='white')
# Out:
# <ipython-input-49-53cd16561b5c>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='player_name', y='awards', data=motm_with_names.nlargest(10,'awards'), palette='viridis')

# %% [markdown]
# <b> Virat Kholi has won the most Man-of-the-Match awards followed by Muhammad Nabi and Sikandar Raza</b>

# %% [markdown]
# # Highest wicket takers in T20 Internationals

# %%
bowling_data.head()
# Out:
#    match_id  innings         team opposition  bowler_id  overs  balls  \
# 0    300436        1  New Zealand    England    10303.0    4.0   24.0
# 1    300436        1  New Zealand    England     9711.0    4.0   24.0
# 2    300436        1  New Zealand    England    10325.0    3.0   18.0
# 3    300436        1  New Zealand    England    49108.0    4.0   24.0
# 4    300436        1  New Zealand    England     9570.0    3.0   18.0
#
#    maidens  conceded  wickets  economy  dots  fours  sixes  wides  noballs
# 0      0.0      35.0      1.0     8.75  10.0    3.0    2.0    1.0      0.0
# 1      0.0      45.0      1.0    11.25   5.0    6.0    1.0    1.0      0.0
# 2      0.0      43.0      2.0    14.33   5.0    3.0    4.0    1.0      0.0
# 3      0.0      22.0      2.0     5.50  10.0    1.0    1.0    0.0      0.0
# 4      0.0      25.0      0.0     8.33   8.0    3.0    1.0    0.0      0.0

# %%
# Grouping data by bowler ids and aggregating balls, wickets and economy
bowlers_record = bowling_data.groupby('bowler_id')[['balls', 'wickets', 'economy']].agg(
    {'balls' : 'sum',
     'wickets' : 'sum',
     'economy' : 'mean'})

# Extracting top 10 bowlers by wickets
top_10_bowlers = bowlers_record.nlargest(10, 'wickets')

# Merging dataframe with players info
top_10_bowlers_names = top_10_bowlers.merge(players_info, left_index=True, right_on='player_id')

# Setting size and theme
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')

# Plotting with balls bowled on x-axis and economy on y-axis
ax = sns.scatterplot(x='balls', y='economy', data=top_10_bowlers_names, size='wickets', hue='player_name', sizes=(100,200))

# Customizing legend
plt.legend(bbox_to_anchor=(1.07, 1), loc='upper left', borderaxespad=0)

# Annotating points on the plot with wickets and economy
for lab,row in top_10_bowlers_names.iterrows():
    ax.annotate(f"W: { int(row['wickets']) }\nE: { round(row['economy'],2) }", xy=(row['balls']+15, row['economy']-0.025))

# Customizing the chart
ax.set_title("Highest wicket takers in T20I", fontweight = 'bold', fontsize=15)
ax.set_xlabel("Balls bowled", fontweight = 'bold')
ax.set_ylabel("Economy", fontweight = 'bold')

plt.show()

# %% [markdown]
# <b><li>Rashid Khan is the most economical bowler with 130 wickets <br>
# <b><li>Tim Southee has the highest wickets uptill now but also with a high economy

# %% [markdown]
# # Highest run scorers in T20 Internationals

# %%
batting_data.head()
# Out:
#    match_id  innings      team  batsman  runs  balls  fours  sixes  \
# 0    361657        1  Zimbabwe  10423.0  53.0   38.0    5.0    3.0
# 1    361657        1  Zimbabwe  49282.0  12.0   22.0    2.0    0.0
# 2    361657        1  Zimbabwe  47619.0   8.0   26.0    0.0    0.0
# 3    361657        1  Zimbabwe  10421.0   4.0    6.0    1.0    0.0
# 4    361660        1  Pakistan  11647.0  44.0   41.0    4.0    1.0
#
#    strikeRate isOut wicketType   fielders   bowler
# 0      139.47  True    run out  ['47099']      NaN
# 1       54.54  True     caught  ['47738']   8270.0
# 2       30.76  True     caught  ['19596']  47099.0
# 3       66.66  True     caught   ['8270']   4169.0
# 4      107.31  True     caught  ['15267']  50377.0

# %%
batsman_records = batting_data.pivot_table(values=['runs', 'balls', 'fours', 'sixes', 'strikeRate', 'isOut'], index='batsman',
                         aggfunc={'runs': 'sum', 'balls' : 'sum', 'fours' : 'sum', 'sixes' : 'sum', 'strikeRate' : 'mean', 'isOut' : 'sum'})

top_10_batsman = batsman_records.nlargest(10,'runs').reset_index()

top_10_batsman['batting_avg'] = top_10_batsman['runs'] / top_10_batsman['isOut']

top_10_batsman_names = top_10_batsman.merge(players_info, left_on='batsman', right_on='player_id')

top_10_batsman_names
# Out:
#    batsman   balls  fours isOut    runs  sixes  strikeRate batting_avg  \
# 0  49752.0  2905.0  356.0    76  4008.0  117.0  123.425047   52.736842
# 1  48405.0  2767.0  348.0   123  3853.0  182.0  116.962286   31.325203
# 2  48927.0  2602.0  309.0   111  3531.0  173.0  121.606356   31.810811
# 3  56880.0  2714.0  371.0    84  3485.0   53.0  109.595408   41.488095
# 4  52631.0  2533.0  399.0   122  3438.0  123.0  115.188647   28.180328
# 5  35812.0  2189.0  309.0    91  3120.0  125.0  119.522136   34.285714
# 6  48739.0  2048.0  295.0    88  2894.0  105.0  124.308081   32.886364
# 7  53271.0  1984.0  255.0    82  2861.0  120.0  127.807379   34.890244
# 8  54018.0  2197.0  243.0    57  2797.0   74.0  106.798219   49.070175
# 9  19647.0  2060.0  251.0    95  2514.0   76.0  107.168056   26.463158
#
#    player_id  player_object_id      player_name         dob  dod  \
# 0      49752            253802      Virat Kohli  1988-11-05  NaN
# 1      48405             34102     Rohit Sharma  1987-04-30  NaN
# 2      48927            226492   Martin Guptill  1986-09-30  NaN
# 3      56880            348144       Babar Azam  1994-10-15  NaN
# 4      52631            303427    Paul Stirling  1990-09-03  NaN
# 5      35812              5334      Aaron Finch  1986-11-17  NaN
# 6      48739            219889     David Warner  1986-10-27  NaN
# 7      53271            308967      Jos Buttler  1990-09-08  NaN
# 8      54018            323389  Mohammad Rizwan  1992-06-01  NaN
# 9      19647             41434  Mohammad Hafeez  1980-10-17  NaN
#
#     batting_style           bowling_style  country_id
# 0  right-hand bat        right-arm medium         6.0
# 1  right-hand bat      right-arm offbreak         6.0
# 2  right-hand bat      right-arm offbreak         5.0
# 3  right-hand bat      right-arm offbreak         7.0
# 4  right-hand bat      right-arm offbreak        29.0
# 5  right-hand bat  slow left-arm orthodox         2.0
# 6   left-hand bat                legbreak         2.0
# 7  right-hand bat                     NaN         1.0
# 8  right-hand bat                     NaN         7.0
# 9  right-hand bat      right-arm offbreak         7.0

# %%
# Setting size and theme
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')

# Plotting with balls bowled on x-axis and economy on y-axis
ax = sns.scatterplot(x='runs', y='strikeRate', data=top_10_batsman_names, size='batting_avg',
                     hue='player_name', sizes=(100,250), palette='Paired')

# Customizing legend
plt.legend(bbox_to_anchor=(1.07, 1), loc='upper left', borderaxespad=0)

# Annotating points on the plot with wickets and economy
for lab,row in top_10_batsman_names.iterrows():
    ax.annotate(f"R: { int(row['runs']) }\nA: {round(row['batting_avg'],2)}", xy=(row['runs']+30, row['strikeRate']-0.5))

# Customizing the chart
ax.set_title("Highest run scorers in T20I", fontweight = 'bold', fontsize=15)
ax.set_xlabel("Runs scored", fontweight = 'bold')
ax.set_ylabel("Strike rate", fontweight = 'bold')

plt.show()

# %% [markdown]
# <b><li>Highest Run scorer is Virat Kohli with 4008 runs with average of 52.74<br><li> Jos Buttler has the highest strike rate.<br><li> Babar Azam has scored 3485 runs with average of 41.49

# %% [markdown]
# # Who hit most sixes?

# %%
batsman_records.head()
# Out:
#          balls  fours  isOut   runs  sixes  strikeRate
# batsman
# 1934.0    12.0    2.0   True   10.0    0.0      83.330
# 1939.0    13.0    0.0      2    3.0    0.0      23.610
# 1979.0     8.0    0.0   True    5.0    0.0      62.500
# 1988.0   487.0   76.0     27  629.0   23.0      96.322
# 2034.0    15.0    0.0  False   11.0    1.0      73.330

# %%
# Filter top 5 players with most sixes and merging it with player info dataframe
top_5_sixes = batsman_records.nlargest(5,'sixes')
top_5_sixes_names = top_5_sixes.merge(players_info, left_index=True, right_on='player_id')

# Setting size and theme
plt.figure(figsize=(8,6))
sns.set_style('darkgrid')

# Plotting values and setting title and labels
ax = sns.barplot(x='player_name', y='sixes', data=top_5_sixes_names.sample(5), palette='husl')
ax.set_title("Most sixes in T20Is", fontweight = 'bold', fontsize=15)
ax.set_xlabel("Players", fontweight = 'bold', fontsize=13)
ax.set_ylabel("Sixes", fontweight = 'bold', fontsize=13)

# Setting label on each bar
for container in ax.containers:
    ax.bar_label(container, padding=-30, fontsize = 17, color='white')
# Out:
# <ipython-input-56-c3b9fd4a1234>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='player_name', y='sixes', data=top_5_sixes_names.sample(5), palette='husl')

# %% [markdown]
# <b><li> Rohit Sharma has hitted most sixes till now i.e 182

# %% [markdown]
# # Most successful teams in T20Is

# %%
matches_data.head(2)
# Out:
#     t20i_match_no  match_id                          match_name  series_id  \
# 10              1    211048  New Zealand Vs Australia Only T20I     238218
# 11              2    211028      England Vs Australia Only T20I     238219
#
#                                           series_name match_date match_format  \
# 10    Australia tour of New Zealand  - 2005 (2004/05)        NaT          T20
# 11  Australia tour of England and Scotland  - 2005...        NaT          T20
#
#     team1_id team1_name  team1_captain  ...  match_venue_(city)  \
# 10         2  Australia           2230  ...            Auckland
# 11         1    England           4709  ...         Southampton
#
#     match_venue_(country)  toss_winner  toss_winner_choice match_winner  \
# 10            New Zealand    Australia                 bat    Australia
# 11                England      England                 bat      England
#
#            match_result_text  mom_player  \
# 10  Australia won by 44 runs      2230.0
# 11   England won by 100 runs      8107.0
#
#                                      team1_playing_11  \
# 10  ['4176', '8876', '4382', '2230', '2066', '6259...
# 11  ['3865', '34719', '4271', '8107', '4709', '231...
#
#                                      team2_playing_11  \
# 10  ['10384', '2121', '7410', '9570', '5619', '193...
# 11  ['4176', '2119', '4382', '8876', '6256', '2230...
#
#                                         debut_players
# 10  ['4176', '4176', '10316', '4382', '10384', '10...
# 11  ['4271', '7023', '2160', '34719', '2286', '228...
#
# [2 rows x 30 columns]

# %%
# Grouping by match winners and counting them
matches_win_countries = matches_data.pivot_table(values='match_id', index='match_winner', aggfunc='count').reset_index()

# Renaming and extracting 10 largest
top_10_countries = matches_win_countries.rename(columns={'match_id':'matches_won', 'match_winner' : 'country'}).nlargest(10,'matches_won')

plt.figure(figsize=(10,6))
sns.set_style('darkgrid')

# Plotting
ax =sns.barplot(x='matches_won', y='country', data=top_10_countries, label="Won", palette='rocket')

# Customizaitons
ax.set_title("Most succesful teams in T20Is", fontweight = 'bold', fontsize=15)
ax.set_xlabel("Matches won", fontweight = 'bold', fontsize=13)
ax.set_ylabel("Teams", fontweight = 'bold', fontsize=13)

# Setting label on each bar
for container in ax.containers:
    ax.bar_label(container, padding=-35, fontsize = 17, color='white')

plt.show()
# Out:
# <ipython-input-58-2cf03b67ac36>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax =sns.barplot(x='matches_won', y='country', data=top_10_countries, label="Won", palette='rocket')

# %% [markdown]
# # **All uptill now!**
